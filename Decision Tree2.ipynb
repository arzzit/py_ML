# %%
import pandas as pd

# %%
titanic = pd.read_csv(r'D:\titanic.csv')

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
titanic['sex_n']= le.fit_transform(titanic['Sex'])

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
target = titanic['Survived']

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
titanic_new =titanic.drop(['Pclass','PassengerId','Survived','Name','Sex','SibSp','Parch','Ticket','Cabin','Embarked'],axis = 'columns')

# %%
titanic_new
# Out:
#       Age     Fare  sex_n
# 0    22.0   7.2500      1
# 1    38.0  71.2833      0
# 2    26.0   7.9250      0
# 3    35.0  53.1000      0
# 4    35.0   8.0500      1
# ..    ...      ...    ...
# 886  27.0  13.0000      1
# 887  19.0  30.0000      0
# 888   NaN  23.4500      0
# 889  26.0  30.0000      1
# 890  32.0   7.7500      1
#
# [891 rows x 3 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn import tree
tr = tree.DecisionTreeClassifier()

# %%
age_mean=titanic_new.Age.mean()

# %%
age_mean
# Out:
# 29.69911764705882

# %%
titanic_new.Age.fillna(age_mean)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
titanic_new
# Out:
#       Age     Fare  sex_n
# 0    22.0   7.2500      1
# 1    38.0  71.2833      0
# 2    26.0   7.9250      0
# 3    35.0  53.1000      0
# 4    35.0   8.0500      1
# ..    ...      ...    ...
# 886  27.0  13.0000      1
# 887  19.0  30.0000      0
# 888   NaN  23.4500      0
# 889  26.0  30.0000      1
# 890  32.0   7.7500      1
#
# [891 rows x 3 columns]

# %%
titanic_new.Age.replace(['NaN'],29.6)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic_new
# Out:
#       Age     Fare  sex_n
# 0    22.0   7.2500      1
# 1    38.0  71.2833      0
# 2    26.0   7.9250      0
# 3    35.0  53.1000      0
# 4    35.0   8.0500      1
# ..    ...      ...    ...
# 886  27.0  13.0000      1
# 887  19.0  30.0000      0
# 888   NaN  23.4500      0
# 889  26.0  30.0000      1
# 890  32.0   7.7500      1
#
# [891 rows x 3 columns]

# %%
from sklearn import tree

# %%
tr = tree.DecisionTreeClassifier()

# %%
age=titanic_new.Age.dropna()
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
titanic_new.rename

# %%
titanic_new=titanic_new.drop('age',axis = 'columns')

# %%
titanic_new.Age=titanic_new.Age.fillna(26)

# %%
titanic_new
# Out:
#       Age     Fare  sex_n
# 0    22.0   7.2500      1
# 1    38.0  71.2833      0
# 2    26.0   7.9250      0
# 3    35.0  53.1000      0
# 4    35.0   8.0500      1
# ..    ...      ...    ...
# 886  27.0  13.0000      1
# 887  19.0  30.0000      0
# 888  26.0  23.4500      0
# 889  26.0  30.0000      1
# 890  32.0   7.7500      1
#
# [891 rows x 3 columns]

# %%
tr.fit(titanic_new,target)
# Out:
# DecisionTreeClassifier()

# %%
tr.score(titanic_new,target)
# Out:
# 0.978675645342312

# %%
tr.predict([[28,7.2500,1]])
# Out:
# array([0], dtype=int64)
